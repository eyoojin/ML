# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/train.csv')
df2 = pd.read_csv('data/test.csv')

# %%
cond1 = df['Sex'] == 'male'
male_mean = df.loc[cond1, 'Age'].mean()
df.loc[cond1, 'Age'] = df.loc[cond1, 'Age'].fillna(male_mean)

cond2 = df['Sex'] == 'female'
female_mean = df.loc[cond2, 'Age'].mean()
df.loc[cond2, 'Age'] = df.loc[cond2, 'Age'].fillna(female_mean)

# %%
cond1 = df2['Sex'] == 'male'
male_mean = df2.loc[cond1, 'Age'].mean()
df2.loc[cond1, 'Age'] = df2.loc[cond1, 'Age'].fillna(male_mean)

cond2 = df2['Sex'] == 'female'
female_mean = df2.loc[cond2, 'Age'].mean()
df2.loc[cond2, 'Age'] = df2.loc[cond2, 'Age'].fillna(female_mean)

# %%
df2['Fare'] = df2['Fare'].fillna(0)

# %%
target = df['Survived']
features = ['Pclass', 'Sex', 'Fare', 'Age']


data = pd.get_dummies(df[features])
test = pd.get_dummies(df2[features])

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=5)
dt.fit(data, target)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
perdictions = dt.predict(test)

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# ---

# %%
df3 = pd.concat([df, df2])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1132 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
cond1 = df3['Sex'] == 'male'
male_mean = df3.loc[cond1, 'Age'].mean()

cond2 = df2['Sex'] == 'male'
df2.loc[cond2, 'Age'] = df2.loc[cond2, 'Age'].fillna(male_mean)

cond3 = df3['Sex'] == 'female'
female_mean = df3.loc[cond3, 'Age'].mean()

cond4 = df2['Sex'] == 'female'
df2.loc[cond4, 'Age'] = df2.loc[cond4, 'Age'].fillna(female_mean)

# %%
cond5 = df3['Pclass'] == 3
fare_mean = df3.loc[cond5, 'Fare'].mean()
cond6 = df2['Pclass'] == 3
df2.loc[cond6, 'Fare'] = df2.loc[cond6, 'Fare'].fillna(0)

# %%
target = df['Survived']
features = ['Pclass', 'Sex', 'Fare', 'Age','Embarked']
data = pd.get_dummies(df[features])
test = pd.get_dummies(df2[features])

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, n_jobs=-1)
scores = cross_validate(rf, data, target, n_jobs=-1)
print(scores)
# Out:
# {'fit_time': array([0.17895627, 0.17152476, 0.16272926, 0.17169237, 0.17582488]), 'score_time': array([0.02828884, 0.02861953, 0.02855563, 0.02800131, 0.02804875]), 'test_score': array([0.7877095 , 0.80337079, 0.84831461, 0.78651685, 0.82022472])}

# %%
rf = RandomForestClassifier(n_estimators=200, n_jobs=-1)
scores = cross_validate(rf, data, target, n_jobs=-1)
print(scores)
# Out:
# {'fit_time': array([0.38148904, 0.37315083, 0.38279605, 0.38127232, 0.37533307]), 'score_time': array([0.03845692, 0.03950953, 0.03857684, 0.03920197, 0.03979135]), 'test_score': array([0.78212291, 0.80337079, 0.84831461, 0.79775281, 0.84269663])}

# %%
scores = cross_validate(dt, data, target, n_jobs=-1)
print(scores)
# Out:
# {'fit_time': array([0.00324869, 0.00519586, 0.00482774, 0.00393558, 0.00373936]), 'score_time': array([0.00215101, 0.00227356, 0.00217915, 0.00182748, 0.0020504 ]), 'test_score': array([0.74301676, 0.80898876, 0.83146067, 0.79213483, 0.83707865])}

# %%
rf = RandomForestClassifier(n_jobs = -1)
rf.fit(data, target)
predictions = rf.predict(test)

# %%
output = pd.DataFrame({'PassengerId': df2.PassengerId, 'Survived': predictions})
output.to_csv('submission.csv', index=False)

# %%
print(male_mean)
print(female_mean)
print(fare_mean)
# Out:
# 30.58522796352584
# 28.68708762886598
# 13.302888700564973

# %%
test
# Out:
#      Pclass      Fare        Age  Sex_female  Sex_male
# 0         3    7.8292  34.500000       False      True
# 1         3    7.0000  47.000000        True     False
# 2         2    9.6875  62.000000       False      True
# 3         3    8.6625  27.000000       False      True
# 4         3   12.2875  22.000000        True     False
# ..      ...       ...        ...         ...       ...
# 413       3    8.0500  30.585228       False      True
# 414       1  108.9000  39.000000        True     False
# 415       3    7.2500  38.500000       False      True
# 416       3    8.0500  30.585228       False      True
# 417       3   22.3583  30.585228       False      True
#
# [418 rows x 5 columns]

# %%
rf = RandomForestClassifier(n_jobs=-1)
scores = cross_validate(rf, data, target, return_train_score=True, n_jobs=-1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB
